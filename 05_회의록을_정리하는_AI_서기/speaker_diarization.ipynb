# %% [markdown]
# ### 문장과 화자 구분하기
#
# 화자를 구분하는 기능은 pyannote.audio 를 이용해서 개발할 수 있다.

# %%
# !pip install pyannote.audio
# !pip install numpy
# Out:
# Collecting pyannote.audio
#   Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl.metadata (11 kB)
# Collecting asteroid-filterbanks>=0.4 (from pyannote.audio)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting einops>=0.6.0 (from pyannote.audio)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pyannote.audio) (0.34.4)
# Collecting lightning>=2.0.1 (from pyannote.audio)
#   Downloading lightning-2.5.3-py3-none-any.whl.metadata (39 kB)
# Collecting omegaconf<3.0,>=2.1 (from pyannote.audio)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyannote.core>=5.0.0 (from pyannote.audio)
#   Using cached pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database>=5.0.1 (from pyannote.audio)
#   Using cached pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyannote.metrics>=3.2 (from pyannote.audio)
#   Using cached pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline>=3.0.1 (from pyannote.audio)
#   Downloading pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# Collecting pytorch-metric-learning>=2.1.0 (from pyannote.audio)
#   Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting rich>=12.0.0 (from pyannote.audio)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting semver>=3.0.0 (from pyannote.audio)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pyannote.audio) (0.13.1)
# Collecting speechbrain>=1.0.0 (from pyannote.audio)
#   Downloading speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Collecting tensorboardX>=2.6 (from pyannote.audio)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=2.0.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pyannote.audio) (2.8.0+cu128)
# Collecting torch-audiomentations>=0.11.0 (from pyannote.audio)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torchaudio>=2.2.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pyannote.audio) (2.8.0+cu128)
# Collecting torchmetrics>=0.11.0 (from pyannote.audio)
#   Downloading torchmetrics-1.8.1-py3-none-any.whl.metadata (22 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<3.0,>=2.1->pyannote.audio)
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (6.0.2)
# Requirement already satisfied: numpy in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (2.3.2)
# Requirement already satisfied: typing-extensions in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (4.14.1)
# Requirement already satisfied: filelock in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (25.0)
# Requirement already satisfied: requests in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (1.1.7)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0.1->pyannote.audio)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting pytorch-lightning (from lightning>=2.0.1->pyannote.audio)
#   Downloading pytorch_lightning-2.5.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.12.15)
# Requirement already satisfied: setuptools in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.1->pyannote.audio) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (1.14.0)
# Requirement already satisfied: networkx in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (3.5)
# Requirement already satisfied: jinja2 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from torch>=2.0.0->pyannote.audio) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.10)
# Collecting sortedcontainers>=2.0.4 (from pyannote.core>=5.0.0->pyannote.audio)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting scipy>=1.1 (from pyannote.core>=5.0.0->pyannote.audio)
#   Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas>=0.19 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pyannote.database>=5.0.1->pyannote.audio) (2.3.1)
# Collecting typer>=0.12.1 (from pyannote.database>=5.0.1->pyannote.audio)
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Collecting scikit-learn>=0.17.1 (from pyannote.metrics>=3.2->pyannote.audio)
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting docopt>=0.6.2 (from pyannote.metrics>=3.2->pyannote.audio)
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tabulate>=0.7.7 (from pyannote.metrics>=3.2->pyannote.audio)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting matplotlib>=2.0.0 (from pyannote.metrics>=3.2->pyannote.audio)
#   Downloading matplotlib-3.10.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio)
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio)
#   Downloading fonttools-4.59.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (107 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio)
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: pillow>=8 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (11.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting optuna>=3.1 (from pyannote.pipeline>=3.0.1->pyannote.audio)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio)
#   Downloading sqlalchemy-2.0.43-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: six>=1.5 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->pyannote.audio)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from rich>=12.0.0->pyannote.audio) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from soundfile>=0.12.1->pyannote.audio) (1.17.1)
# Requirement already satisfied: pycparser in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio) (2.22)
# Collecting hyperpyyaml (from speechbrain>=1.0.0->pyannote.audio)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting sentencepiece (from speechbrain>=1.0.0->pyannote.audio)
#   Downloading sentencepiece-0.2.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio)
#   Downloading greenlet-3.2.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->pyannote.audio) (1.3.0)
# Collecting protobuf>=3.20 (from tensorboardX>=2.6->pyannote.audio)
#   Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting julius<0.3,>=0.2.3 (from torch-audiomentations>=0.11.0->pyannote.audio)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch-audiomentations>=0.11.0->pyannote.audio)
#   Downloading torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio)
#   Downloading primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting click>=8.0.0 (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->pyannote.audio) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2025.8.3)
# Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 27.1 MB/s  0:00:00
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading lightning-2.5.3-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.2/824.2 kB 27.0 MB/s  0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.1-py3-none-any.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 31.1 MB/s  0:00:00
# Using cached pyannote.core-5.0.0-py3-none-any.whl (58 kB)
# Using cached pyannote.database-5.1.3-py3-none-any.whl (48 kB)
# Using cached pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
# Downloading matplotlib-3.10.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 90.8 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 78.5 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.9 MB/s  0:00:00
# Downloading pyannote.pipeline-3.0.1-py3-none-any.whl (31 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 90.6 MB/s  0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 83.5 MB/s  0:00:00m0:00:01:00:01
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading speechbrain-1.0.3-py3-none-any.whl (864 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 27.2 MB/s  0:00:00
# Downloading sqlalchemy-2.0.43-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.9 MB/s  0:00:00
# Downloading greenlet-3.2.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 kB 19.8 MB/s  0:00:00
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Using cached protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading torch_audiomentations-0.12.0-py3-none-any.whl (48 kB)
# Downloading torch_pitch_shift-1.2.5-py3-none-any.whl (5.0 kB)
# Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 22.6 MB/s  0:00:00
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pytorch_lightning-2.5.3-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.2/828.2 kB 26.0 MB/s  0:00:00
# Downloading sentencepiece-0.2.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 43.5 MB/s  0:00:00
# Building wheels for collected packages: antlr4-python3-runtime, docopt, julius
#   DEPRECATION: Building 'antlr4-python3-runtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'antlr4-python3-runtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144591 sha256=564a5e568de54e1ac1f5d9613070cb175c18d574cfad135e05a6cffc5ccb0f7e
#   Stored in directory: /home/haiqv/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   DEPRECATION: Building 'docopt' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'docopt'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13783 sha256=8c4f6efd3e0f3f08d62db1d2279f6286709bcdcf52d54ab45307951d6b0c672a
#   Stored in directory: /home/haiqv/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   DEPRECATION: Building 'julius' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'julius'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21966 sha256=a7be0ca879314759209db2ba8370e150c854d8e45744a5de609d7e547922cc51
#   Stored in directory: /home/haiqv/.cache/pip/wheels/16/15/d4/edd724cefe78050a6ba3344b8b0c6672db829a799dbb9f81ff
# Successfully built antlr4-python3-runtime docopt julius
# Installing collected packages: sortedcontainers, primePy, docopt, antlr4-python3-runtime, threadpoolctl, tabulate, shellingham, sentencepiece, semver, scipy, ruamel.yaml.clib, pyparsing, protobuf, omegaconf, mdurl, Mako, lightning-utilities, kiwisolver, joblib, greenlet, fonttools, einops, cycler, contourpy, colorlog, click, tensorboardX, sqlalchemy, scikit-learn, ruamel.yaml, pyannote.core, matplotlib, markdown-it-py, rich, hyperpyyaml, alembic, typer, torchmetrics, pytorch-metric-learning, optuna, julius, asteroid-filterbanks, torch-pitch-shift, speechbrain, pytorch-lightning, pyannote.database, torch-audiomentations, pyannote.pipeline, pyannote.metrics, lightning, pyannote.audio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 [pyannote.audio]te.audio]ing]ipeline]ons]g]
# Successfully installed Mako-1.3.10 alembic-1.16.4 antlr4-python3-runtime-4.9.3 asteroid-filterbanks-0.4.0 click-8.2.1 colorlog-6.9.0 contourpy-1.3.3 cycler-0.12.1 docopt-0.6.2 einops-0.8.1 fonttools-4.59.0 greenlet-3.2.4 hyperpyyaml-1.2.2 joblib-1.5.1 julius-0.2.7 kiwisolver-1.4.9 lightning-2.5.3 lightning-utilities-0.15.2 markdown-it-py-4.0.0 matplotlib-3.10.5 mdurl-0.1.2 omegaconf-2.3.0 optuna-4.4.0 primePy-1.3 protobuf-6.31.1 pyannote.audio-3.3.2 pyannote.core-5.0.0 pyannote.database-5.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-3.0.1 pyparsing-3.2.3 pytorch-lightning-2.5.3 pytorch-metric-learning-2.8.1 rich-14.1.0 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 scikit-learn-1.7.1 scipy-1.16.1 semver-3.0.4 sentencepiece-0.2.1 shellingham-1.5.4 sortedcontainers-2.4.0 speechbrain-1.0.3 sqlalchemy-2.0.43 tabulate-0.9.0 tensorboardX-2.6.4 threadpoolctl-3.6.0 torch-audiomentations-0.12.0 torch-pitch-shift-1.2.5 torchmetrics-1.8.1 typer-0.16.0
# Requirement already satisfied: numpy in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (2.3.2)

# %%
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path='../.env')
hf_token = os.getenv("HUGGINGFACE_TOKEN")  # 환경 변수에서 API 키를 가져오기

# instantiate the pipeline
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token=hf_token)

# cuda가 사용 가능한 경우 cuda를 사용하도록 설정
import torch
if torch.cuda.is_available():
    pipeline.to(torch.device("cuda"))
    print('cuda is available')
else:
    print('cuda is not available')

# run the pipeline on an audio file
# diarization = pipeline("audio.wav")

# dump the diarization output to disk using RTTM format
# with open("audio.rttm", "w") as rttm:
#    diarization.write_rttm(rttm)

diarization = pipeline("./audio/싼기타_비싼기타.mp3")

# dump the diarization output to disk using RTTM format
with open("싼기타_비싼기타.rttm", "w", encoding='utf-8') as rttm:
    diarization.write_rttm(rttm)
# Out:
# cuda is available
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1839.)
#   std = sequences.std(dim=-1, correction=1)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# ...
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/pyannote/audio/core/io.py:85: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   info = torchaudio.info(file["audio"], backend=backend)
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/soundfile_backend.py:120: UserWarning: torchaudio._backend.common.AudioMetaData has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return AudioMetaData(
# /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(

# %%
# RTTM을 CSV로 변환
import pandas as pd
rttm_path = "./싼기타_비싼기타.rttm"

df_rttm = pd.read_csv(
    rttm_path,      # rttm 파일 경로
    sep=' ',        # 구분자는 띄어쓰기
    header=None,    # 헤더는 없음
    names=['type', 'file', 'chnl', 'start', 'duration', 'C1', 'C2', 'speaker_id', 'C3', 'C4'] 
)

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.776 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.504     0.844 NaN NaN  SPEAKER_00 NaN NaN
#
# [88 rows x 10 columns]

# %%
# 발언이 끝난 시간 추가히기
# start + duration을 end로 변환
df_rttm['end'] = df_rttm['start'] + df_rttm['duration']

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.776 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.504     0.844 NaN NaN  SPEAKER_00 NaN NaN
#
#         end
# 0     6.798
# 1    11.388
# 2    16.686
# 3    27.875
# 4    30.204
# ..      ...
# 83  417.451
# 84  421.231
# 85  424.420
# 86  428.268
# 87  429.348
#
# [88 rows x 11 columns]

# %%
# 연속된 발화를 기록하기 위해 number 변수 추가하기

df_rttm["number"] = None	# number 열 만들고 None으로 초기화
df_rttm.at[0, "number"] = 0

for i in range(1, len(df_rttm)):
    if df_rttm.at[i, "speaker_id"] != df_rttm.at[i-1, "speaker_id"]:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"] + 1
    else:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"]

display(df_rttm.head(10))
# Out:
#       type      file  chnl   start  duration  C1  C2  speaker_id  C3  C4  \
# 0  SPEAKER  싼기타_비싼기타     1   0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1  SPEAKER  싼기타_비싼기타     1   7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2  SPEAKER  싼기타_비싼기타     1  11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3  SPEAKER  싼기타_비싼기타     1  17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4  SPEAKER  싼기타_비싼기타     1  28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# 5  SPEAKER  싼기타_비싼기타     1  32.414     0.759 NaN NaN  SPEAKER_00 NaN NaN
# 6  SPEAKER  싼기타_비싼기타     1  33.545     3.561 NaN NaN  SPEAKER_00 NaN NaN
# 7  SPEAKER  싼기타_비싼기타     1  37.628     3.763 NaN NaN  SPEAKER_00 NaN NaN
# 8  SPEAKER  싼기타_비싼기타     1  41.611     1.097 NaN NaN  SPEAKER_00 NaN NaN
# 9  SPEAKER  싼기타_비싼기타     1  41.645     0.810 NaN NaN  SPEAKER_01 NaN NaN
#
#       end number
# 0   6.798      0
# 1  11.388      0
# 2  16.686      0
# 3  27.875      0
# 4  30.204      0
# 5  33.173      1
# 6  37.106      1
# 7  41.391      1
# 8  42.708      1
# 9  42.455      2

# %%
# 같은 화자끼리 묶어서 정리하기
df_rttm_grouped = df_rttm.groupby("number").agg(
    start=pd.NamedAgg(column='start', aggfunc='min'),
    end=pd.NamedAgg(column='end', aggfunc='max'),
    speaker_id=pd.NamedAgg(column='speaker_id', aggfunc='first')
)

display(df_rttm_grouped)
# Out:
#           start      end  speaker_id
# number
# 0         0.993   30.204  SPEAKER_01
# 1        32.414   42.708  SPEAKER_00
# 2        41.645   44.024  SPEAKER_01
# 3        45.813   67.109  SPEAKER_00
# 4        67.227   82.786  SPEAKER_01
# 5        84.659  102.564  SPEAKER_00
# 6       103.492  117.532  SPEAKER_01
# 7       119.759  138.676  SPEAKER_00
# 8       139.351  168.967  SPEAKER_01
# 9       170.907  192.321  SPEAKER_00
# 10      192.322  193.689  SPEAKER_01
# 11      192.760  193.503  SPEAKER_00
# 12      193.823  216.571  SPEAKER_01
# 13      218.579  238.120  SPEAKER_00
# 14      238.120  238.677  SPEAKER_01
# 15      238.188  239.352  SPEAKER_00
# 16      239.858  240.651  SPEAKER_01
# 17      240.297  241.006  SPEAKER_00
# 18      241.040  251.334  SPEAKER_01
# 19      253.696  271.550  SPEAKER_00
# 20      272.140  304.557  SPEAKER_01
# 21      306.970  326.022  SPEAKER_00
# 22      326.360  335.472  SPEAKER_01
# 23      337.548  355.925  SPEAKER_00
# 24      356.245  363.974  SPEAKER_01
# 25      365.982  381.423  SPEAKER_00
# 26      382.165  383.734  SPEAKER_01
# 27      385.726  397.184  SPEAKER_00
# 28      397.623  399.108  SPEAKER_01
# 29      401.437  406.601  SPEAKER_00
# 30      407.326  408.338  SPEAKER_01
# 31      410.093  417.451  SPEAKER_00
# 32      417.755  421.231  SPEAKER_01
# 33      423.644  429.348  SPEAKER_00

# %%
# 발화 시간 추가하고 인덱스 제거하기
df_rttm_grouped["duration"] = df_rttm_grouped["end"] - df_rttm_grouped["start"]
df_rttm_grouped = df_rttm_grouped.reset_index(drop=True)
display(df_rttm_grouped)
# Out:
#       start      end  speaker_id  duration
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# 21  306.970  326.022  SPEAKER_00    19.052
# 22  326.360  335.472  SPEAKER_01     9.112
# 23  337.548  355.925  SPEAKER_00    18.377
# 24  356.245  363.974  SPEAKER_01     7.729
# 25  365.982  381.423  SPEAKER_00    15.441
# 26  382.165  383.734  SPEAKER_01     1.569
# 27  385.726  397.184  SPEAKER_00    11.458
# 28  397.623  399.108  SPEAKER_01     1.485
# 29  401.437  406.601  SPEAKER_00     5.164
# 30  407.326  408.338  SPEAKER_01     1.012
# 31  410.093  417.451  SPEAKER_00     7.358
# 32  417.755  421.231  SPEAKER_01     3.476
# 33  423.644  429.348  SPEAKER_00     5.704

# %%
# 화자 분리 결과를 csv 파일로 저장하기
df_rttm_grouped.to_csv(
    "싼기타_비싼기타_rttm.csv",
    sep=',',
    index=False
)
