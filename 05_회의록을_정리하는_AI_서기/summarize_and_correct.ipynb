# %% [markdown]
# ### 전체 회의 내용 요약하기
#
# 앞서 만들었던 csv 파일에서 SPEAKER_00, SPEAKER_01 로 표시되었던 부분에 화자의 이름을 넣고 GPT 에게 회의 내용 요약을 요청해 보자

# %%
# 회의록 csv 파일 열기
import pandas as pd

meeting_note_csv_path = "./audio/싼기타_비싼기타_final.csv"
df_rttm = pd.read_csv(meeting_note_csv_path, sep="|")

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# 21  306.970  326.022  SPEAKER_00    19.052
# 22  326.360  335.472  SPEAKER_01     9.112
# 23  337.548  355.925  SPEAKER_00    18.377
# 24  356.245  363.974  SPEAKER_01     7.729
# 25  365.982  381.423  SPEAKER_00    15.441
# 26  382.165  383.734  SPEAKER_01     1.569
# 27  385.726  397.184  SPEAKER_00    11.458
# 28  397.623  399.108  SPEAKER_01     1.485
# 29  401.437  406.601  SPEAKER_00     5.164
# 30  407.326  408.338  SPEAKER_01     1.012
# 31  410.093  417.451  SPEAKER_00     7.358
# 32  417.755  421.231  SPEAKER_01     3.476
# 33  423.644  429.348  SPEAKER_00     5.704
#
#                                                  text
# 0    지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을...
# 1    좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형...
# 2                                     네 됐어요. 시작하시죠.\n
# 3    좋아요.\n 먼저 3기타로 시작하는게\n 좋은 이유를 말씀드리겠습니다.\n 초보자...
# 4    아, 저는 지금 말에 어폐가 있다고 생각해요.\n 왜냐하면 어차피 지금 비싼 기타...
# 5    그런데 비싼 기타로 시작하면\n 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지...
# 6    싼 기타를 뭐하러 또 삽니까?\n 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없...
# 7    하하, 기타를 망치로 치진 않지만\n 그래도 초보자들은 실수도 많고\n 조심스럽게...
# 8    충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n 많이 좋아...
# 9    하하\n 역시 좋은 기타를 사면 책임감도\n 더 커진다는 말씀이시군요 그래도 비싼...
# 10                                                NaN
# 11                                                NaN
# 12   아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러...
# 13   하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n 하지만 반대로 비싼...
# 14                                                NaN
# 15                                   결국은 본인이 선택한...\n
# 16                                                NaN
# 17                                                NaN
# 18   근데 그게 비싼 기타를 치면 더 편해요.\n 편하게 치는 게 중요하다고 하셨잖아요...
# 19   맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n 하지만 초보자 입장...
# 20   아 그 말에 대해 동의를 합니다.\n 기타를 잘 못 치는 사람은\n 쌍기타와 비싼...
# 21   하하! 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n 하지만 비싼 기...
# 22   맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n 비싼 기타를 사면 꾸준히 연습...
# 23   그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n 하지만...
# 24   아, 맞아요.\n 지금 얘기하신 거 보니까\n 쌍기타가 더 좋다는 얘기는 안 하시...
# 25   아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n 재...
# 26                                 어? 지금 도망가시는 건가요?\n
# 27   아니요. 전혀 그렇지 않아요.\n 전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요...
# 28                                                NaN
# 29        아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n
# 30                                        화난 것 같은데?\n
# 31   네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n 계속해서 이하고 나누고 ...
# 32              아니요. 화나셨는데 굳이 더 할 필요 없죠. 그만 잊지 마시죠.\n
# 33   알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니...

# %%
# 실제 이름 넣기
name_dict = {
    "SPEAKER_00": "AI",
    "SPEAKER_01": "진우",
}

df_rttm["name"] = df_rttm["speaker_id"].apply(lambda x: name_dict[x])

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# 21  306.970  326.022  SPEAKER_00    19.052
# 22  326.360  335.472  SPEAKER_01     9.112
# 23  337.548  355.925  SPEAKER_00    18.377
# 24  356.245  363.974  SPEAKER_01     7.729
# 25  365.982  381.423  SPEAKER_00    15.441
# 26  382.165  383.734  SPEAKER_01     1.569
# 27  385.726  397.184  SPEAKER_00    11.458
# 28  397.623  399.108  SPEAKER_01     1.485
# 29  401.437  406.601  SPEAKER_00     5.164
# 30  407.326  408.338  SPEAKER_01     1.012
# 31  410.093  417.451  SPEAKER_00     7.358
# 32  417.755  421.231  SPEAKER_01     3.476
# 33  423.644  429.348  SPEAKER_00     5.704
#
#                                                  text name
# 0    지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을...   진우
# 1    좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형...   AI
# 2                                     네 됐어요. 시작하시죠.\n   진우
# 3    좋아요.\n 먼저 3기타로 시작하는게\n 좋은 이유를 말씀드리겠습니다.\n 초보자...   AI
# 4    아, 저는 지금 말에 어폐가 있다고 생각해요.\n 왜냐하면 어차피 지금 비싼 기타...   진우
# 5    그런데 비싼 기타로 시작하면\n 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지...   AI
# 6    싼 기타를 뭐하러 또 삽니까?\n 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없...   진우
# 7    하하, 기타를 망치로 치진 않지만\n 그래도 초보자들은 실수도 많고\n 조심스럽게...   AI
# 8    충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n 많이 좋아...   진우
# 9    하하\n 역시 좋은 기타를 사면 책임감도\n 더 커진다는 말씀이시군요 그래도 비싼...   AI
# 10                                                NaN   진우
# 11                                                NaN   AI
# 12   아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러...   진우
# 13   하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n 하지만 반대로 비싼...   AI
# 14                                                NaN   진우
# 15                                   결국은 본인이 선택한...\n   AI
# 16                                                NaN   진우
# 17                                                NaN   AI
# 18   근데 그게 비싼 기타를 치면 더 편해요.\n 편하게 치는 게 중요하다고 하셨잖아요...   진우
# 19   맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n 하지만 초보자 입장...   AI
# 20   아 그 말에 대해 동의를 합니다.\n 기타를 잘 못 치는 사람은\n 쌍기타와 비싼...   진우
# 21   하하! 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n 하지만 비싼 기...   AI
# 22   맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n 비싼 기타를 사면 꾸준히 연습...   진우
# 23   그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n 하지만...   AI
# 24   아, 맞아요.\n 지금 얘기하신 거 보니까\n 쌍기타가 더 좋다는 얘기는 안 하시...   진우
# 25   아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n 재...   AI
# 26                                 어? 지금 도망가시는 건가요?\n   진우
# 27   아니요. 전혀 그렇지 않아요.\n 전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요...   AI
# 28                                                NaN   진우
# 29        아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n   AI
# 30                                        화난 것 같은데?\n   진우
# 31   네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n 계속해서 이하고 나누고 ...   AI
# 32              아니요. 화나셨는데 굳이 더 할 필요 없죠. 그만 잊지 마시죠.\n   진우
# 33   알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니...   AI

# %%
# 요약을 위해 필요한 정보만 추출하기
meeting_note_txt = df_rttm[['start', 'end', 'name', 'text']].to_json(orient='records', force_ascii=False)
print(meeting_note_txt)
# Out:
# [{"start":0.993,"end":30.204,"name":"진우","text":" 지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.\n 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게\n 그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n 아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n 이거를 입장을 나눠가지고\n 저랑 토론해보면 좋을 것 같아요.\n 두 중에 어떤 역할 맡으실래요?\n"},{"start":32.414,"end":42.708,"name":"AI","text":" 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?\n 네 맞아요. 준비 되셨나요?\n"},{"start":41.645,"end":44.024,"name":"진우","text":" 네 됐어요. 시작하시죠.\n"},{"start":45.813,"end":67.109,"name":"AI","text":" 좋아요.\n 먼저 3기타로 시작하는게\n 좋은 이유를 말씀드리겠습니다.\n 초보자일때는\n 실수도 많고 기타에 익숙해지는\n 과정이 필요하니까 비싼 기타보다는\n 부담없이 연습할 수 있는\n 싼 기타가 좋다고 봅니다.\n 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n 성형님은 어떻게 생각하세요?\n"},{"start":67.227,"end":82.786,"name":"진우","text":" 아, 저는 지금 말에 어폐가 있다고 생각해요.\n 왜냐하면 어차피 지금 비싼 기타로\n 나중에 살 생각을 하는 거잖아요.\n 그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.\n"},{"start":84.659,"end":102.564,"name":"AI","text":" 그런데 비싼 기타로 시작하면\n 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?\n 초보 때는 실습을 많이 하니까 더 크지 않을까요?\n 초보 때는 실습을 많이 하니까\n 쌍기타로 마음 편히 연습할 수 있는게\n 더 좋다고 생각해요.\n 그리고 기타 현지에 익숙해지면\n 그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데\n"},{"start":103.492,"end":117.532,"name":"진우","text":" 싼 기타를 뭐하러 또 삽니까?\n 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요\n 기타를 망치로 치는 것도 아니라 손가락으로 치는 건데\n 기타를 싼 거 산다고 달라지나요?\n"},{"start":119.759,"end":138.676,"name":"AI","text":" 하하, 기타를 망치로 치진 않지만\n 그래도 초보자들은 실수도 많고\n 조심스럽게 다루기 어려울 수 있잖아요.\n 비싼 기타를 사기 전에\n 부담없이 연습하면서\n 자신감을 키우는 것도 중요하다고 생각해요\n 그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.\n 그리고 쌍기타도 요즘은\n 품질이 꽤 좋아서 연습용으로\n"},{"start":139.351,"end":168.967,"name":"진우","text":" 충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n 많이 좋아서\n 연습하는데 충분한 거는\n 맞는데\n 근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?\n 그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.\n 근데 기타가 좋은 기타다.\n 그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요\n"},{"start":170.907,"end":192.321,"name":"AI","text":" 하하\n 역시 좋은 기타를 사면 책임감도\n 더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.\n 쌍기타로 시작해서\n 부담없이 연습하고\n 정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고\n 정말 기타에 흥미가 생기면\n 그때 비싼 기타로 넘어가는 것도 좋은 방법이죠\n"},{"start":192.322,"end":193.689,"name":"진우","text":null},{"start":192.76,"end":193.503,"name":"AI","text":null},{"start":193.823,"end":216.571,"name":"진우","text":" 아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?\n 라는 생각이 들면서 계속\n 연습을 열심히 할 수가 있어요.\n 그래서 포기를 안 하게 되는\n 측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다.\n"},{"start":218.579,"end":238.12,"name":"AI","text":" 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n 하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?\n 특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요. 그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.\n"},{"start":238.12,"end":238.677,"name":"진우","text":null},{"start":238.188,"end":239.352,"name":"AI","text":" 결국은 본인이 선택한...\n"},{"start":239.858,"end":240.651,"name":"진우","text":null},{"start":240.297,"end":241.006,"name":"AI","text":null},{"start":241.04,"end":251.334,"name":"진우","text":" 근데 그게 비싼 기타를 치면 더 편해요.\n 편하게 치는 게 중요하다고 하셨잖아요.\n 근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.\n"},{"start":253.696,"end":271.55,"name":"AI","text":" 맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n 하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.\n 그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.\n 결국 각자의 스타일과 상황에 맞게\n 선택하는 게 최선이겠네요.\n"},{"start":272.14,"end":304.557,"name":"진우","text":" 아 그 말에 대해 동의를 합니다.\n 기타를 잘 못 치는 사람은\n 쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지\n 이걸 잘 못 느끼긴 하죠.\n 근데 반대로\n 비싼 기타를 치던 사람이\n 싼 기타를 치면은 아 이게\n 이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다\n 그래서 처음부터 비싼 기타를 쳐서\n 그런 쌍기타의 맛을 모르고 살아도 되는데\n 왜 그 맛없는 맛을\n 굳이 초반부터 느끼려고 합니까?\n 그러니까 비싼 기타로 시작을 하는 게 좋죠.\n"},{"start":306.97,"end":326.022,"name":"AI","text":" 하하! 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n 하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니\n 처음엔 가볍게 접근하는 게 더 좋다고 봅니다.\n 어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?\n"},{"start":326.36,"end":335.472,"name":"진우","tex ...

# %%
# 회의록 작성을 요청하는 프롬프트 작성하기
system_prompt = f'''
너는 회의 내용을 요약하는 봇이다. 아래 회의록을 읽고, 주요 내용을 요약하라.
결과는 마크다운 형식으로 작성한다.

아래 형식에 맞추어 작성하라.

# 회의 제목

## 주요 내용

## 참석자별 입장

## 결정 사항   

=============== 이하 회의록 ===============

{ meeting_note_txt }
'''

# %%
# 오픈AI API 설정
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="../.env")
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
# OpenAI API를 사용해 요약 결과 생성
response = client.chat.completions.create(
    model='gpt-4o',
    temperature=0.1,
    messages=[
        {"role": "system", "content": system_prompt},
    ]
)

# (4) 요약 결과를 파일로 저장
summary = response.choices[0].message.content 
summary = summary.strip() # 좌우 공백 제거

print(summary)
# Out:
# # 기타 구매 토론 회의
#
# ## 주요 내용
# 이번 회의는 기타를 처음 시작할 때 싼 기타로 시작하는 것이 좋은지, 비싼 기타로 시작하는 것이 좋은지에 대한 토론이었다. 두 가지 입장을 나누어 각자의 의견을 제시하며 논의가 진행되었다.
#
# ## 참석자별 입장
# - **진우**: 비싼 기타로 시작하는 것이 좋다고 주장했다. 이유는 이중 지출을 막을 수 있고, 비싼 기타가 연습에 대한 동기부여가 될 수 있으며, 기타의 품질 차이를 느끼면서 더 열심히 연습할 수 있다고 설명했다.
# - **AI**: 싼 기타로 시작하는 것이 좋다고 주장했다. 초보자에게는 부담 없이 연습할 수 있는 환경이 중요하며, 기타에 흠집이 나거나 실수할 때 부담이 적다는 점을 강조했다. 또한, 기타에 대한 흥미가 생기면 그때 비싼 기타로 업그레이드하는 것도 좋은 방법이라고 설명했다.
#
# ## 결정 사항
# 결정적인 결론은 도출되지 않았으며, 각자의 스타일과 상황에 맞게 기타를 선택하는 것이 최선이라는 의견으로 마무리되었다. 중요한 것은 기타를 꾸준히 연습하는 열정과 노력이라는 점에 참석자들이 동의했다.

# %%
# 요약 결과를 파일로 저장
with open("./audio/meeting_summary.md", "w", encoding="utf-8") as f:
    f.write(summary)

# %% [markdown]
# ### GPT로 녹취록 교정하기
#
# STT 원본을 GPT로 교정하기

# %%
# 메시지 하나씩 GPT에게 확인받고 수정하기
df_meeting_note = df_rttm[['start', 'end', 'name', 'text']].copy()
df_meeting_note.dropna(inplace=True)

meeting_note_dict = df_meeting_note.to_dict(orient='records')  # 딕셔너리 형태로 변환
meeting_note_dict
# Out:
# [{'start': 0.993,
#   'end': 30.204,
#   'name': '진우',
#   'text': ' 지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.\n 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게\n 그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n 아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n 이거를 입장을 나눠가지고\n 저랑 토론해보면 좋을 것 같아요.\n 두 중에 어떤 역할 맡으실래요?\n'},
#  {'start': 32.414,
#   'end': 42.708,
#   'name': 'AI',
#   'text': ' 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?\n 네 맞아요. 준비 되셨나요?\n'},
#  {'start': 41.645, 'end': 44.024, 'name': '진우', 'text': ' 네 됐어요. 시작하시죠.\n'},
#  {'start': 45.813,
#   'end': 67.10900000000001,
#   'name': 'AI',
#   'text': ' 좋아요.\n 먼저 3기타로 시작하는게\n 좋은 이유를 말씀드리겠습니다.\n 초보자일때는\n 실수도 많고 기타에 익숙해지는\n 과정이 필요하니까 비싼 기타보다는\n 부담없이 연습할 수 있는\n 싼 기타가 좋다고 봅니다.\n 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n 성형님은 어떻게 생각하세요?\n'},
#  {'start': 67.227,
#   'end': 82.786,
#   'name': '진우',
#   'text': ' 아, 저는 지금 말에 어폐가 있다고 생각해요.\n 왜냐하면 어차피 지금 비싼 기타로\n 나중에 살 생각을 하는 거잖아요.\n 그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.\n'},
#  {'start': 84.659,
#   'end': 102.564,
#   'name': 'AI',
#   'text': ' 그런데 비싼 기타로 시작하면\n 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?\n 초보 때는 실습을 많이 하니까 더 크지 않을까요?\n 초보 때는 실습을 많이 하니까\n 쌍기타로 마음 편히 연습할 수 있는게\n 더 좋다고 생각해요.\n 그리고 기타 현지에 익숙해지면\n 그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데\n'},
#  {'start': 103.492,
#   'end': 117.532,
#   'name': '진우',
#   'text': ' 싼 기타를 뭐하러 또 삽니까?\n 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요\n 기타를 망치로 치는 것도 아니라 손가락으로 치는 건데\n 기타를 싼 거 산다고 달라지나요?\n'},
#  {'start': 119.759,
#   'end': 138.67600000000002,
#   'name': 'AI',
#   'text': ' 하하, 기타를 망치로 치진 않지만\n 그래도 초보자들은 실수도 많고\n 조심스럽게 다루기 어려울 수 있잖아요.\n 비싼 기타를 사기 전에\n 부담없이 연습하면서\n 자신감을 키우는 것도 중요하다고 생각해요\n 그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.\n 그리고 쌍기타도 요즘은\n 품질이 꽤 좋아서 연습용으로\n'},
#  {'start': 139.351,
#   'end': 168.96699999999998,
#   'name': '진우',
#   'text': ' 충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n 많이 좋아서\n 연습하는데 충분한 거는\n 맞는데\n 근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?\n 그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.\n 근데 기타가 좋은 기타다.\n 그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요\n'},
#  {'start': 170.907,
#   'end': 192.321,
#   'name': 'AI',
#   'text': ' 하하\n 역시 좋은 기타를 사면 책임감도\n 더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.\n 쌍기타로 시작해서\n 부담없이 연습하고\n 정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고\n 정말 기타에 흥미가 생기면\n 그때 비싼 기타로 넘어가는 것도 좋은 방법이죠\n'},
#  {'start': 193.823,
#   'end': 216.571,
#   'name': '진우',
#   'text': ' 아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?\n 라는 생각이 들면서 계속\n 연습을 열심히 할 수가 있어요.\n 그래서 포기를 안 하게 되는\n 측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다.\n'},
#  {'start': 218.579,
#   'end': 238.12,
#   'name': 'AI',
#   'text': ' 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n 하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?\n 특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요. 그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.\n'},
#  {'start': 238.188, 'end': 239.352, 'name': 'AI', 'text': ' 결국은 본인이 선택한...\n'},
#  {'start': 241.04,
#   'end': 251.334,
#   'name': '진우',
#   'text': ' 근데 그게 비싼 기타를 치면 더 편해요.\n 편하게 치는 게 중요하다고 하셨잖아요.\n 근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.\n'},
#  {'start': 253.696,
#   'end': 271.55,
#   'name': 'AI',
#   'text': ' 맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n 하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.\n 그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.\n 결국 각자의 스타일과 상황에 맞게\n 선택하는 게 최선이겠네요.\n'},
#  {'start': 272.14,
#   'end': 304.557,
#   'name': '진우',
#   'text': ' 아 그 말에 대해 동의를 합니다.\n 기타를 잘 못 치는 사람은\n 쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지\n 이걸 잘 못 느끼긴 하죠.\n 근데 반대로\n 비싼 기타를 치던 사람이\n 싼 기타를 치면은 아 이게\n 이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다\n 그래서 처음부터 비싼 기타를 쳐서\n 그런 쌍기타의 맛을 모르고 살아도 되는데\n 왜 그 맛없는 맛을\n 굳이 초반부터 느끼려고 합니까?\n 그러니까 비싼 기타로 시작을 하는 게 좋죠.\n'},
#  {'start': 306.97,
#   'end': 326.02200000000005,
#   'name': 'AI',
#   'text': ' 하하! 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n 하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니\n 처음엔 가볍게 접근하는 게 더 좋다고 봅니다.\n 어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?\n'},
#  {'start': 326.36,
#   'end': 335.472,
#   'name': '진우',
#   'text': ' 맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n 비싼 기타를 사면 꾸준히 연습을 하게 됩니다.\n 왜냐하면 계속 그 기타를 만지고 있고 싶거든요.\n 왜냐면 감촉도 훨씬 좋고 그러니까요.\n'},
#  {'start': 337.548,
#   'end': 355.925,
#   'name': 'AI',
#   'text': ' 그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n 하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.\n 결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.\n 소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.\n'},
#  {'start': 356.245,
#   'end': 363.974,
#   'name': '진우',
#   'text': ' 아, 맞아요.\n 지금 얘기하신 거 보니까\n 쌍기타가 더 좋다는 얘기는 안 하시네요.\n'},
#  {'start': 365.982,
#   'end': 381.423,
#   'name': 'AI',
#   'text': ' 아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n 재밌게 이야기 나누는 게 더 중요한 것 같아요.\n 가짜 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다.\n 결국 중요한 건 기타를 사랑하는 마음이겠죠.\n 앞으로도 즐겁게 연습하시길 바래요.\n'},
#  {'start': 382.165,
#   'end': 383.734,
#   'name': '진우',
#   'text': ' 어? 지금 도망가시는 건가요?\n'},
#  {'start': 385.726,
#   'end': 397.184,
#   'name': 'AI',
#   'text': ' 아니요. 전혀 그렇지 않아요.\n 전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.\n 토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다.\n 혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?\n'},
#  {'start': 401.437,
#   'end': 406.601,
#   'name': 'AI',
#   'text': ' 아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n'},
#  {'start': 407.326, 'end': 408.338, 'name': '진우', 'text': ' 화난 것 같은데?\n'},
#  {'start': 410.093,
#   'end': 417.451,
#   'name': 'AI',
#   'text': ' 네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n 계속해서 이하고 나누고 싶으시면 편하게 말씀해주세요.\n'},
#  {'start': 417.755,
#   'end': 421.231,
#   'name': '진우',
#   'text': ' 아니요. 화나셨는데 굳이 더 할 필요 없죠. 그만 잊지 마시죠.\n'},
#  {'start': 423.644,
#   'end': 429.348,
#   'name': 'AI',
#   'text': ' 알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.\n'}]

# %%
for row in meeting_note_dict:    
    if not isinstance(row['text'], str): # 텍스트가 아닌 다른 형식인 경우 통과
        continue

    correction_system_prompt = f'''
        너는 주어진 회의 녹취록을 수정 및 보완하는 봇이다.
        주어진 회의 녹취록은 STT로 작성된 결과이므로, 이 중에 오류가 있는 부분을 찾아내고 수정하라.

        표현, 말투는 최대한 원본과 일치하도록 유지하되, 잘못 받아적은 내용을 수정하라.
        원본의 내용을 최대한 살리되, 잘못된 내용만 수정하라. 
        어떤 경우에는 A라는 사람이 말한 내용을 B가 말한 것으로 잘못 기록된 경우도 있을 수 있다. 이런 경우에는 문맥을 고려하여 수정하라.

        원본 내용 중 빠지거나, 추가되거나, 잘못 기록된 부분을 찾아내어 수정하라. 수정된 메시지 이외에는 아무것도 작성하지 말라.
        --------------------------------
        회의 요약문 : {summary}
        --------------------------------
        회의 녹취록 전문: {df_meeting_note.to_json(orient='records', force_ascii=False)}
        --------------------------------
        확인할 메시지 원본: {row['text']}
    '''

    response = client.chat.completions.create(
        model='gpt-4o',
        temperature=0.1,
        messages=[
            {"role": "system", "content": correction_system_prompt},
        ]
    )

    correction = response.choices[0].message.content
    if ':' in correction:  # “수정: “ 과 같은 형식으로 반환되는 경우 해결 
        correction = correction.split(':')[-1]
        
    correction = correction.strip() # 좌우 공백 제거

    print(row['name'])
    print(row['text'])
    print(correction)
    print('-----------------')

    row['corrected_text'] = correction
# Out:
# 진우
#  지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.
#  그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게
#  그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐
#  아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐
#  이거를 입장을 나눠가지고
#  저랑 토론해보면 좋을 것 같아요.
#  두 중에 어떤 역할 맡으실래요?
#
# 지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다. 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게 그리고 주제는 싼 기타로 시작하는 게 좋으냐 아니면 비싼 기타로 시작하는 게 좋으냐 이거를 입장을 나눠가지고 저랑 토론해보면 좋을 것 같아요. 두 중에 어떤 역할 맡으실래요?
# -----------------
# AI
#  좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?
#  네 맞아요. 준비 되셨나요?
#
# 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 진우님은 비싼 기타로 시작하는 게 좋다는 입장이시죠? 네 맞아요. 준비 되셨나요?
# -----------------
# 진우
#  네 됐어요. 시작하시죠.
#
# 네, 됐어요. 시작하시죠.
# -----------------
# AI
#  좋아요.
#  먼저 3기타로 시작하는게
#  좋은 이유를 말씀드리겠습니다.
#  초보자일때는
#  실수도 많고 기타에 익숙해지는
#  과정이 필요하니까 비싼 기타보다는
#  부담없이 연습할 수 있는
#  싼 기타가 좋다고 봅니다.
#  무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?
#  성형님은 어떻게 생각하세요?
#
# 좋아요. 먼저 싼 기타로 시작하는 게 좋은 이유를 말씀드리겠습니다. 초보자일 때는 실수도 많고 기타에 익숙해지는 과정이 필요하니까 비싼 기타보다는 부담 없이 연습할 수 있는 싼 기타가 좋다고 봅니다. 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드하는 것도 나쁘지 않죠? 진우님은 어떻게 생각하세요?
# -----------------
# 진우
#  아, 저는 지금 말에 어폐가 있다고 생각해요.
#  왜냐하면 어차피 지금 비싼 기타로
#  나중에 살 생각을 하는 거잖아요.
#  그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.
#
# 아, 저는 지금 말에 어폐가 있다고 생각해요. 왜냐하면 어차피 지금 싼 기타로 시작하고 나중에 비싼 기타로 살 생각을 하는 거잖아요. 그럼 어차피 싼 기타 사고 비싼 기타를 사게 되는데 그런 이중 지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.
# -----------------
# AI
#  그런데 비싼 기타로 시작하면
#  혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?
#  초보 때는 실습을 많이 하니까 더 크지 않을까요?
#  초보 때는 실습을 많이 하니까
#  쌍기타로 마음 편히 연습할 수 있는게
#  더 좋다고 생각해요.
#  그리고 기타 현지에 익숙해지면
#  그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데
#
# 그런데 비싼 기타로 시작하면 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요? 초보 때는 실수가 많으니까 부담이 더 크지 않을까요? 초보 때는 실수가 많으니까 싼 기타로 마음 편히 연습할 수 있는 게 더 좋다고 생각해요. 그리고 기타에 익숙해지면 그때 비싼 기타를 사는 게 더 의미 있지 않을까요?
# -----------------
# 진우
#  싼 기타를 뭐하러 또 삽니까?
#  그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요
#  기타를 망치로 치는 것도 아니라 손가락으로 치는 건데
#  기타를 싼 거 산다고 달라지나요?
#
# 싼 기타를 뭐하러 또 삽니까?
# 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요.
# 기타를 망치로 치는 것도 아니고 손가락으로 치는 건데,
# 기타를 싼 거 산다고 달라지나요?
# -----------------
# AI
#  하하, 기타를 망치로 치진 않지만
#  그래도 초보자들은 실수도 많고
#  조심스럽게 다루기 어려울 수 있잖아요.
#  비싼 기타를 사기 전에
#  부담없이 연습하면서
#  자신감을 키우는 것도 중요하다고 생각해요
#  그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.
#  그리고 쌍기타도 요즘은
#  품질이 꽤 좋아서 연습용으로
#
# 하하, 기타를 망치로 치진 않지만 그래도 초보자들은 실수도 많고 조심스럽게 다루기 어려울 수 있잖아요. 비싼 기타를 사기 전에 부담없이 연습하면서 자신감을 키우는 것도 중요하다고 생각해요. 그리고 싼 기타도 요즘은 품질이 꽤 좋아서 연습용으로 충분하다고 생각해요.
# -----------------
# 진우
#  충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이
#  많이 좋아서
#  연습하는데 충분한 거는
#  맞는데
#  근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?
#  그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.
#  근데 기타가 좋은 기타다.
#  그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요
#
# 충분하죠. 아 맞아요. 그것도 맞는 말이에요. 싼 기타도 요새 품질이 많이 좋아서 연습하는데 충분한 거는 맞는데 근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요? 그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠. 근데 기타가 좋은 기타다. 그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요.
# -----------------
# AI
#  하하
#  역시 좋은 기타를 사면 책임감도
#  더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.
#  쌍기타로 시작해서
#  부담없이 연습하고
#  정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고
#  정말 기타에 흥미가 생기면
#  그때 비싼 기타로 넘어가는 것도 좋은 방법이죠
#
# 하하
# 역시 좋은 기타를 사면 책임감도
# 더 커진다는 말씀이시군요. 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.
# 싼 기타로 시작해서
# 부담없이 연습하고
# 정말 기타에 흥미가 생기면 그때 비싼 기타로 넘어가는 것도 좋은 방법이죠.
# -----------------
# 진우
#  아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?
#  라는 생각이 들면서 계속
#  연습을 열심히 할 수가 있어요.
#  그래서 포기를 안 하게 되는
#  측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다.
#
# 아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 좋잖아요. 그러니까 흥미를 더 쉽게 유지할 수 있어요. 그리고 비싼 기타를 사면 흥미를 잃게 되더라도 "어, 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?"라는 생각이 들면서 계속 연습을 열심히 할 수가 있어요. 그래서 포기를 안 하게 되는 측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다.
# -----------------
# AI
#  하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.
#  하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?
#  특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요. 그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.
#
# 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요. 하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요? 특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요. 그리고 좋은 기타로 나중에 업그레이드할 때 그 성취감도 크니까요.
# -----------------
# AI
#  결국은 본인이 선택한...
#
# 결국은 본인이 선택한 기타에 따라 연습하는 것이 중요하겠죠.
# -----------------
# 진우
#  근데 그게 비싼 기타를 치면 더 편해요.
#  편하게 치는 게 중요하다고 하셨잖아요.
#  근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.
#
# 근데 그게 비싼 기타를 치면 더 편해요.
# 편하게 치는 게 중요하다고 하셨잖아요.
# 근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇겠어요?
# -----------------
# AI
#  맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.
#  하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.
#  그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.
#  결국 각자의 스타일과 상황에 맞게
#  선택하는 게 최선이겠네요.
#
# 맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.
# 하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.
# 그래서 싼 기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.
# 결국 각자의 스타일과 상황에 맞게 선택하는 게 최선이겠네요.
# -----------------
# 진우
#  아 그 말에 대해 동의를 합니다.
#  기타를 잘 못 치는 사람은
#  쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지
#  이걸 잘 못 느끼긴 하죠.
#  근데 반대로
#  비싼 기타를 치던 사람이
#  싼 기타를 치면은 아 이게
#  이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다
#  그래서 처음부터 비싼 기타를 쳐서
#  그런 쌍기타의 맛을 모르고 살아도 되는데
#  왜 그 맛없는 맛을
#  굳이 초반부터 느끼려고 합니까?
#  그러니까 비싼 기타로 시작을 하는 게 좋죠.
#
# 아 그 말에 대해 동의를 합니다.
# 기타를 잘 못 치는 사람은
# 싼 기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지
# 이걸 잘 못 느끼긴 하죠.
# 근데 반대로
# 비싼 기타를 치던 사람이
# 싼 기타를 치면은 아 이게
# 이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다
# 그래서 처음부터 비싼 기타를 쳐서
# 그런 싼 기타의 맛을 모르고 살아도 되는데
# 왜 그 맛없는 맛을
# 굳이 초반부터 느끼려고 합니까?
# 그러니까 비싼 기타로 시작을 하는 게 좋죠.
# -----------------
# AI
#  하하! 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요
#  하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니
#  처음엔 가볍게 접근하는 게 더 좋다고 봅니다.
#  어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?
#
# 하하! 싼 기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요. 하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니 처음엔 가볍게 접근하는 게 더 좋다고 봅니다. 어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?
# -----------------
# 진우
#  맞아요. 그래서 비싼 기타를 사야 되는 거예요.
#  비싼 기타를 사면 꾸준히 연습을 하게 됩니다.
#  왜냐하면 계속 그 기타를 만지고 있고 싶거든요.
#  왜냐면 감촉도 훨씬 좋고 그러니까요.
#
# 맞아요. 그래서 비싼 기타를 사야 되는 거예요. 비싼 기타를 사면 꾸준히 연습을 하게 됩니다. 왜냐하면 계속 그 기타를 만지고 있고 싶거든요. 왜냐하면 감촉도 훨씬 좋고 그러니까요.
# -----------------
# AI
#  그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.
#  하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.
#  결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.
#  소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.
#
# 그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.
# 하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.
# 결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.
# 소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.
# -----------------
# 진우
#  아, 맞아요.
#  지금 얘기하신 거 보니까
#  쌍기타가 더 좋다는 얘기는 안 하시네요.
#
# 아, 맞아요.
# 지금 얘기하신 거 보니까
# 싼 기타가 더 좋다는 얘기는 안 하시네요.
# -----------------
# AI
#  아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는
#  재밌게 이야기 나누는 게 더 중요한 것 같아요.
#  가짜 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다.
#  결국 중요한 건 기타를 사랑하는 마음이겠죠.
#  앞으로도 즐겁게 연습하시길 바래요.
#
# 아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는 재밌게 이야기 나누는 게 더 중요한 것 같아요. 각자 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다. 결국 중요한 건 기타를 사랑하는 마음이겠죠. 앞으로도 즐겁게 연습하시길 바래요.
# -----------------
# 진우
#  어? 지금 도망가시는 건가요?
#
# 어? 지금 도망가시는 건가요?
# -----------------
# AI
#  아니요. 전혀 그렇지 않아요.
#  전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.
#  토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다.
#  혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?
#
# 아니요. 전혀 그렇지 않아요. 저는 그냥 즐거운 대화를 나누고 싶었을 뿐이에요. 토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다. 혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?
# -----------------
# AI
#  아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.
#
# 아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하지 마세요.
# -----------------
# 진우
#  화난 것 같은데?
#
# 화난 것 같은데? 걱정하지 마세요.
# -----------------
# AI
#  네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.
#  계속해서 이하고 나누고 싶으시면 편하게 말씀해주세요.
#
# 네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.
# 계속해서 이야기하고 싶으시면 편하게 말씀해주세요.
# -----------------
# 진우
#  아니요. 화나셨는데 굳이 더 할 필요 없죠. 그만 잊지 마시죠.
#
# 아니요. 화나셨는데 굳이 더 할 필요 없죠. 그만 하시죠.
# -----------------
# AI
#  알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.
#
# 알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.
# -----------------

# %%
# 이렇게 만든 meeting_note_dict를 JSON파일 형식으로 저장
import json

with open('./audio/guitar_meeting_note_corrected.json', 'w', encoding='utf-8') as f:
    json.dump(meeting_note_dict, f, ensure_ascii=False, indent=4)

# %%
# 수정한 녹취록을 마크다운 형식으로 출력하기
md_template = ""

for row in meeting_note_dict:
    md_template += f"- **{row['name']}** : {row['corrected_text']}\n"

with open('./audio/guitar_meeting_note_corrected.md', 'w', encoding='utf-8') as f:
    f.write(md_template)

# %%
# 수정한 녹취록을 MS 워드 파일로 출력하기
# python-docx 라이브러리 설치 필요
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Downloading lxml-6.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in /home/haiqv/conda/envs/agent-llm/lib/python3.11/site-packages (from python-docx) (4.14.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading lxml-6.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 25.5 MB/s  0:00:00
# Installing collected packages: lxml, python-docx
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-docx] [python-docx]
# Successfully installed lxml-6.0.0 python-docx-1.2.0

# %%
from docx import Document

document = Document()   # (1)  docx 객체 생성
document.add_heading('회의록', level=1) # (2) 제목 추가

table = document.add_table(rows=1, cols=2) # (3) 테이블 생성
table.style = 'Table Grid' # (4) 테이블 스타일 지정

hdr_cells = table.rows[0].cells # (5) 첫 번째 행에 셀 추가
hdr_cells[0].text = 'Speaker' # (6) 첫 번째 셀에 Speaker 추가
hdr_cells[1].text = 'Content'   # (7) 두 번째 셀에 Content 추가

# (8) 수정된 녹취록 파일을 읽어들여서 테이블에 추가
for row in meeting_note_dict:
    row_cells = table.add_row().cells
    row_cells[0].text = row['name']
    row_cells[1].text = row['corrected_text']


document.save('./audio/guitar_meeting_note_corrected.docx') # (9) docx 파일 저장
